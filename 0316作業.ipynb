# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandra-Su91/bigdata/blob/main/0316%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# function (name, pos = -1L, envir = as.environment(pos), all.names = FALSE,
#     pattern, sorted = TRUE)
# {
#     if (!missing(name)) {
#         pos <- tryCatch(name, error = function(e) e)
#         if (inherits(pos, "error")) {
#             name <- substitute(name)
#             if (!is.character(name))
#                 name <- deparse(name)
#             warning(gettextf("%s converted to character string",
#                 sQuote(name)), domain = NA)
#             pos <- name
#         }
#     }
#     all.names <- .Internal(ls(envir, all.names, sorted))
#     if (!missing(pattern)) {
#         if ((ll <- length(grep("[", pattern, fixed = TRUE))) &&
#             ll != length(grep("]", pattern, fixed = TRUE))) {
#             if (pattern == "[") {
#                 pattern <- "\\["
#                 warning("replaced regular expression pattern '[' by  '\\\\['")
#             }
#             else if (length(grep("[^\\\\]\\[<-", pattern))) {
# ...

# %%
system("ls",TRUE)
# Out:
# [1] "sample_data" ";新 (1).csv"

# %%
library(readr)

# %%
dataset<-read.csv(";新 (1).csv")

# %%
dataset
# Out:
#    government_agency government_agencies address
# 1  消防局            瑞芳分隊            新北市瑞芳區中正路30號
# 2  消防局            金山分隊            新北市金山區南勢54號
# 3  消防局            萬里分隊            新北市萬里區景美里景美路16號
# 4  消防局            石門分隊            新北市石門區中山路64之1號
# 5  消防局            雙溪分隊            新北市雙溪區共和里中山路45號
# 6  消防局            貢寮分隊            新北市貢寮區貢寮里朝陽街66號
# 7  海巡署            深澳安檢所          新北市瑞芳區深澳路189之9號
# 8  海巡署            水湳洞執檢站        新北市瑞芳區明里路90之1號
# 9  海巡署            南雅安檢所          新北市瑞芳區南雅里南雅路41之2號
# 10 海巡署            鼻頭安檢所          新北市瑞芳區鼻頭路101號
# 11 海巡署            水尾執檢站          新北市金山區民生路2號
# 12 海巡署            磺港安檢所          新北市金山區磺港路24之6號
# 13 海巡署            麟山鼻安檢所        新北市石門區德茂里1鄰
# 14 海巡署            富基安檢所          新北市石門區楓林路15之1號
# 15 海巡署            草里執檢站          新北市石門區草里里阿里荖33之2號
# 16 海巡署            石門安檢所          新北市石門區中央路37之1號
# 17 海巡署            龜吼安檢所          新北市萬里區漁澳路85號之3號
# 18 海巡署            萬里安檢所          新北市萬里區獅頭路15之3號
# ...

# %%
head(dataset$government_agencies,n=10)
tail(dataset$address,n=10)
# Out:
#  [1] "瑞芳分隊"     "金山分隊"     "萬里分隊"     "石門分隊"     "雙溪分隊"
#  [6] "貢寮分隊"     "深澳安檢所"   "水湳洞執檢站" "南雅安檢所"   "鼻頭安檢所"
#  [1] "新北市石門區中山路64號"          "新北市石門區老梅路26號"
#  [3] "新北市瑞芳區建基路1段5之1號"     "新北市瑞芳區鼻頭路101號"
#  [5] "新北市瑞芳區濂洞里洞頂路8號"     "新北市貢寮區和美里和美街30號"
#  [7] "新北市貢寮區真理里延平街36號"    "新北市貢寮區福隆里福隆街19號"
#  [9] "新北市金山區磺港路171之2號"      "新北市石門區德茂里下員坑33之6號"

# %%
dataset[grepl("新北市金山區",dataset$address),]
# Out:
#    government_agency government_agencies address                    tel
# 2  消防局            金山分隊            新北市金山區南勢54號       24982519
# 11 海巡署            水尾執檢站          新北市金山區民生路2號      24985120
# 12 海巡署            磺港安檢所          新北市金山區磺港路24之6號  24983746
# 28 警察局            金山派出所          新北市金山區民生路65號     24982009
# 38 北觀處            金山遊客中心        新北市金山區磺港路171之2號 24988980
# 41 消防局            金山分隊            新北市金山區南勢54號       24982519
# 50 海巡署            水尾執檢站          新北市金山區民生路2號      24985120
# 51 海巡署            磺港安檢所          新北市金山區磺港路24之6號  24983746
# 67 警察局            金山派出所          新北市金山區民生路65號     24982009
# 77 北觀處            金山遊客中心        新北市金山區磺港路171之2號 24988980
#    usable_amount_of_life_jacket twd97X   twd97Y  wgs84aX  wgs84aY
# 2  7                            313296.2 2790400 121.6282 25.22096
# 11 7                            315456.2 2790885 121.6496 25.22525
# 12 7                            315467.8 2791404 121.6498 25.22993
# ...

# %%
dataset[grepl("海巡署",dataset$government_agency),]
# Out:
#    government_agency government_agencies address
# 7  海巡署            深澳安檢所          新北市瑞芳區深澳路189之9號
# 8  海巡署            水湳洞執檢站        新北市瑞芳區明里路90之1號
# 9  海巡署            南雅安檢所          新北市瑞芳區南雅里南雅路41之2號
# 10 海巡署            鼻頭安檢所          新北市瑞芳區鼻頭路101號
# 11 海巡署            水尾執檢站          新北市金山區民生路2號
# 12 海巡署            磺港安檢所          新北市金山區磺港路24之6號
# 13 海巡署            麟山鼻安檢所        新北市石門區德茂里1鄰
# 14 海巡署            富基安檢所          新北市石門區楓林路15之1號
# 15 海巡署            草里執檢站          新北市石門區草里里阿里荖33之2號
# 16 海巡署            石門安檢所          新北市石門區中央路37之1號
# 17 海巡署            龜吼安檢所          新北市萬里區漁澳路85號之3號
# 18 海巡署            萬里安檢所          新北市萬里區獅頭路15之3號
# 19 海巡署            東澳執檢站          新北市萬里區東澳8之1號
# 20 海巡署            野柳安檢所          新北市萬里區港東路72之2號
# 21 海巡署            龍洞安檢所          新北市貢寮區龍洞街35之6號
# 22 海巡署            美灩山執檢站        新北市貢寮區美灩山街59之3號
# 23 海巡署            澳底安檢所          新北市貢寮區新港街122號
# 24 海巡署            福隆執檢站          新北市貢寮區東興街6之19號
# 25 海巡署            卯澳執檢站          新北市貢寮區福連里福興街16之1號
# ...

# %%
table(dataset$tel)
# Out:
# 24901074 24901387 24901504 24901553 24909176 24911001 24911066 24911579
#        2        2        2        2        2        2        2        2
# 24921230 24921555 24922739 24923815 24931314 24941314 24961340 24961529
#        4        2        2        2        2        2        2        2
# 24971600 24972009 24977924 24982009 24982475 24982519 24983746 24985120
#        2        2        2        2        2        2        2        2
# 24988980 24991541 24991707 24991882 24991898 26361580 26380564 26380574
#        2        2        2        2        2        2        2        2
# 26380584 26381244 26381272 26381274 26381619 86352548
#        2        2        2        2        2        2

# %%
table(dataset$usable_amount_of_life_jacket)
# Out:
#  7
# 78

# %%
table(dataset$twd97Y)
# Out:
# 2767484.12 2767665.86 2767937.72 2768434.24 2768516.66 2769593.02 2772343.05
#          2          2          2          2          2          2          2
# 2772446.85 2773694.18 2775278.07 2777909.38 2778438.03 2779430.72 2779472.16
#          2          2          2          2          2          2          2
# 2779554.08 2779587.89 2779793.65 2780912.28 2785669.42 2785851.38 2788444.24
#          2          2          4          2          2          2          2
# 2788559.09 2788580.09 2789308.24 2790336.71 2790400.13 2790657.77 2790885.02
#          2          2          2          2          2          2          2
# 2791404.19 2796415.63  2796907.7 2797011.59 2797254.04  2797899.1 2797927.32
#          2          2          2          2          2          2          2
# 2798082.07 2798109.74 2798514.19
#          2          2          2
